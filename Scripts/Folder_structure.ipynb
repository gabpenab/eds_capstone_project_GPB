# %% [markdown]
# GIT USE
# Here I create and organize the folders  and I do the git commits

# %%
# %%bash
# cd "/home/user/capstone project"
# git init
#
# git config --global user.name "Gabriela"
# git config --global user.email "gpena19@gmail.com"
#
# #git status

# %%
import os
from pathlib import Path

# Define project root 
project_path = Path("/home/user/capstone project")

# Create data and scripts directories at the project root
data_path = project_path / "data"
scripts_path = project_path / "scripts"
    
data_path.mkdir(exist_ok=True)
scripts_path.mkdir(exist_ok=True)
    
# Define our 6-folder system inside the data directory
data_folders = [
        "raw_data",
        "processed_data", 
        "analysis",
        "metadata",
        "outputs",
        "archive"
    ]
    
 # Create each data subfolder
for folder in data_folders:
    folder_path = data_path / folder
    folder_path.mkdir(exist_ok=True)

    # Add a README to explain each folder's purpose
    readme_path = folder_path / "README.txt"
 # Write helpful descriptions
    if "raw_data" in folder:
        readme_path.write_text("IMPORTANT: Never modify files in this folder!\nThis is your data vault - keep originals safe here.")
    elif "processed" in folder:
            readme_path.write_text("Place cleaned and processed data here.\nAlways document what processing was done.")
    elif "analysis" in folder:
            readme_path.write_text("Extra analysis docs / notebooks go here.\nOrganize by analysis type or date.")
    elif "metadata" in folder:
            readme_path.write_text("Documentation about your data.\nInclude data dictionaries, collection methods, etc.")
    elif "outputs" in folder:
            readme_path.write_text("Final results, figures, and reports.\nReady to share with others!")
    elif "archive" in folder:
            readme_path.write_text("Old versions and superseded files.\nAlways date your archived files.")
    
    # Add README for scripts folder
    scripts_readme = scripts_path / "README.txt"
    scripts_readme.write_text("Version-controlled scripts and code.\nUse git to track changes to your analysis code.")

# %%
# %%bash
# git add .
# git status
# git commit -m "Updated folder structure and removed old files"
# git remote -v
# git remote add origin https://github.com/gabpenab/eds_capstone_project_GPB
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modifie
# d:   .Folder_structure.ipynb.sage-jupyter2
# 	modified:   Folder_structure.ipynb
# [main 423c694] Updated folder structure and removed old files
#  2 files changed, 55 insertions(+), 3
# deletions(-)

# %%
# %%bash
# git remote remove origin
# git remote add origin https://gabpenab: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@github.com/gabpenab/eds_capstone_project_GPB.git
#
# git push -u origin main
# Out:
# remote: Permission to gabpenab/eds_capstone_project_GPB.git denied to gabpenab.
# fatal: unable to acc
# ess 'https://github.com/gabpenab/eds_capstone_project_GPB.git/': The requested URL returned error: 4
# 03
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'git remote remove origin\ngit remote add origin https://gabpenab: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@github.com/gabpenab/eds_capstone_project_GPB.git\n\ngit push -u origin main\n')
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/magics/script.py:343, in ScriptMagics.shebang(self, line, cell)
#     338 if args.raise_error and p.returncode != 0:
#     339     # If we get here and p.returncode is still None, we must have
#     340     # killed it but not yet seen its return code. We don't wait for it,
#     341     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     342     rc = p.returncode or -9
# --> 343     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'git remote remove origin\ngit remote add origin https://gabpenab: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@github.com/gabpenab/eds_capstone_project_GPB.git\n\ngit push -u origin main\n'' returned non-zero exit status 128.
